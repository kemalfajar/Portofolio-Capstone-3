# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Supermarket Customers.csv', delimiter = '\t')
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      5524        1957  Graduation         Single  58138.0        0
# 1      2174        1954  Graduation         Single  46344.0        1
# 2      4141        1965  Graduation       Together  71613.0        0
# 3      6182        1984  Graduation       Together  26646.0        1
# 4      5324        1981         PhD        Married  58293.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10870        1967  Graduation        Married  61223.0        0
# 2236   4001        1946         PhD       Together  64014.0        2
# 2237   7270        1981  Graduation       Divorced  56981.0        0
# 2238   8235        1956      Master       Together  69245.0        0
# 2239   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %%
#FITUR ENGINEERING

#Count pembelian



#PR
#Keluarin Data Dari salah satu ID yang mengandung 0 di amount pembelian
#Show semua id yang mengandung 0 di amount pembelian

# %%
# Daftar kolom produk
product_cols = ['MntWines', 'MntFruits', 'MntMeatProducts', 
                'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']

# Filter 10 customer yang tidak membeli salah satu produk (nilai 0)
df_zero_purchase = df[df[product_cols].eq(0).any(axis=1)]


# Tampilkan
df_zero_purchase

# 6565
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 5      7446        1967      Master       Together  62513.0        0
# 8      4855        1974         PhD       Together  30351.0        1
# 9      5899        1950         PhD       Together   5648.0        1
# 10     1994        1983  Graduation        Married      NaN        1
# 18     6565        1949      Master        Married  76995.0        0
# ...     ...         ...         ...            ...      ...      ...
# 2224   4286        1970         PhD         Single  57642.0        0
# 2225   4749        1968  Graduation       Together  58554.0        1
# 2227   4201        1962  Graduation         Single  57967.0        0
# 2229  10084        1972  Graduation        Married  24434.0        2
# 2236   4001        1946         PhD       Together  64014.0        2
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %%
# 6565

# %%
# Daftar kolom pembelian produk
product_cols = ['MntWines', 'MntFruits', 'MntMeatProducts',
                'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']

# Hitung jumlah customer yang punya nilai 0 di salah satu produk
jumlah_customer_zero = df[df[product_cols].eq(0).any(axis=1)].shape[0]

print("Jumlah customer yang tidak membeli minimal satu produk:", jumlah_customer_zero)
# Out:
# Jumlah customer yang tidak membeli minimal satu produk: 791

# %%
# Supermarket Customers Data Dictionary
# People
# ● ID: Customer's unique identifier
# ● Year_Birth: Customer's birth year
# ● Education: Customer's education level
# ● Marital_Status: Customer's marital status
# ● Income: Customer's yearly household income
# ● Kidhome: Number of children in customer's household
# ● Teenhome: Number of teenagers in customer's household
# ● Dt_Customer: Date of customer's enrollment with the company
# ● Recency: Number of days since customer's last purchase
# ● Complain: 1 if the customer complained in the last 2 years, 0 otherwise
# Products
# ● MntWines: Amount spent on wine in last 2 years
# ● MntFruits: Amount spent on fruits in last 2 years
# ● MntMeatProducts: Amount spent on meat in last 2 years
# ● MntFishProducts: Amount spent on fish in last 2 years
# ● MntSweetProducts: Amount spent on sweets in last 2 years
# ● MntGoldProds: Amount spent on gold in last 2 years
# Promotion
# ● NumDealsPurchases: Number of purchases made with a discount
# ● AcceptedCmp1: 1 if the customer accepted the offer in the 1st campaign, 0 otherwise
# ● AcceptedCmp2: 1 if the customer accepted the offer in the 2nd campaign, 0 otherwise
# ● AcceptedCmp3: 1 if the customer accepted the offer in the 3rd campaign, 0 otherwise
# ● AcceptedCmp4: 1 if the customer accepted the offer in the 4th campaign, 0 otherwise
# ● AcceptedCmp5: 1 if the customer accepted the offer in the 5th campaign, 0 otherwise
# ● Response: 1 if the customer accepted the offer in the last campaign, 0 otherwise
# Place
# ● NumWebPurchases: Number of purchases made through the company’s website
# ● NumCatalogPurchases: Number of purchases made using a catalog
# ● NumStorePurchases: Number of purchases made directly in stores
# ● NumWebVisitsMonth: Number of visits to the company’s website in the last month

# %%
#Sales Analysis
# 🎯 2️⃣ Product Analysis (Analisis Pembelian Produk)
# ➡️ Analisis:

#Analisis ini akan melihat pembelian produk yang emang paling performing dari antara pembelian yang dilakukan kustomer

#Data 
# Proporsi Pembelian Setiap Produk
#Korelasi antar produk
#Total jumlah Transaksi Antar 
#pemasukkan dari produk

# %%
df = pd.read_csv('Supermarket Customers.csv', delimiter = '\t')
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      5524        1957  Graduation         Single  58138.0        0
# 1      2174        1954  Graduation         Single  46344.0        1
# 2      4141        1965  Graduation       Together  71613.0        0
# 3      6182        1984  Graduation       Together  26646.0        1
# 4      5324        1981         PhD        Married  58293.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10870        1967  Graduation        Married  61223.0        0
# 2236   4001        1946         PhD       Together  64014.0        2
# 2237   7270        1981  Graduation       Divorced  56981.0        0
# 2238   8235        1956      Master       Together  69245.0        0
# 2239   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %%
df.describe()
# Out:
#                  ID   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.info()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data


# Hitung total pembelian untuk masing-masing produk
product_cols = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
total_per_product = df[product_cols].sum()

# Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(total_per_product, labels=product_cols, autopct='%1.1f%%', startangle=140, colors=plt.cm.Pastel1.colors)
plt.title('Proporsi Pembelian per Produk', fontsize=16)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# List kolom produk
product_cols = ['MntWines', 'MntFruits', 'MntMeatProducts', 
                'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']

# Hitung total pembelian per produk
total_per_product = df[product_cols].sum()

# Ubah ke dataframe
product_df = total_per_product.reset_index()
product_df.columns = ['Product', 'TotalSpent']

# --- 📊 Bar Plot ---
plt.figure(figsize=(10, 6))
sns.barplot(data=product_df, x='Product', y='TotalSpent', palette='viridis')

plt.title('Total Pembelian per Produk (Selama 2 Tahun)', fontsize=16)
plt.xlabel('Produk')
plt.ylabel('Total Pembelian')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/3d/nwkkh91j2kn5dq8xnpwchkrm0000gn/T/ipykernel_5499/2418564798.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=product_df, x='Product', y='TotalSpent', palette='viridis')

# %%
import pandas as pd


# Hitung total pembelian dari semua channel
df['TotalPurchases'] = df['NumWebPurchases'] + df['NumCatalogPurchases'] + df['NumStorePurchases']

# Ambil kolom campaign dan pembelian
campaign_cols = ['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5']
purchase_cols = ['NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases','NumDealsPurchases', 'TotalPurchases']

# Hitung korelasi
correlation_table = df[campaign_cols + purchase_cols].corr()

# Ambil hanya korelasi antara campaign dengan pembelian
result = correlation_table.loc[campaign_cols, purchase_cols]

# Tampilkan hasil
print(result.round(2))
# Out:
#               NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# AcceptedCmp1             0.16                 0.31               0.18
# AcceptedCmp2             0.03                 0.10               0.09
# AcceptedCmp3             0.04                 0.10              -0.07
# AcceptedCmp4             0.16                 0.14               0.18
# AcceptedCmp5             0.14                 0.32               0.21
#
#               NumDealsPurchases  TotalPurchases
# AcceptedCmp1              -0.12            0.27
# AcceptedCmp2              -0.04            0.09
# AcceptedCmp3              -0.02            0.03
# AcceptedCmp4               0.02            0.20
# AcceptedCmp5              -0.18            0.28

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Kolom produk
product_cols = ['MntWines', 'MntFruits', 'MntMeatProducts',
                'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']

# --- 1. Hitung Jumlah Transaksi (berapa customer yang beli masing-masing produk) ---
transaction_counts = (df[product_cols] > 0).sum()
transaction_counts.name = 'TransactionCount'

# --- 2. Hitung Total Nominal Pembelian ---
total_amounts = df[product_cols].sum()
total_amounts.name = 'TotalAmount'

# --- 3. Gabungkan ke dalam satu DataFrame ---
summary_df = pd.concat([transaction_counts, total_amounts], axis=1).reset_index()
summary_df.columns = ['Product', 'TransactionCount', 'TotalAmount']

# --- 4. Visualisasi Dua Bar Plot Sampingan ---
plt.figure(figsize=(14, 6))

# Plot Jumlah Transaksi
plt.subplot(1, 2, 1)
sns.barplot(data=summary_df, x='Product', y='TransactionCount', palette='Blues_d')
plt.title('Jumlah Transaksi per Produk')
plt.xlabel('Produk')
plt.ylabel('Jumlah Transaksi')
plt.xticks(rotation=15)

# Plot Total Pembelian (Nominal)
plt.subplot(1, 2, 2)
sns.barplot(data=summary_df, x='Product', y='TotalAmount', palette='Greens_d')
plt.title('Total Pembelian (Nominal) per Produk')
plt.xlabel('Produk')
plt.ylabel('Total Amount')
plt.xticks(rotation=15)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/3d/nwkkh91j2kn5dq8xnpwchkrm0000gn/T/ipykernel_4551/491244909.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=summary_df, x='Product', y='TransactionCount', palette='Blues_d')
# /var/folders/3d/nwkkh91j2kn5dq8xnpwchkrm0000gn/T/ipykernel_4551/491244909.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=summary_df, x='Product', y='TotalAmount', palette='Greens_d')
